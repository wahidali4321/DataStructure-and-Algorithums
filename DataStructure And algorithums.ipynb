# %% [markdown]
# ## List

# %% [markdown]
# ## Creating Lists

# %%
x = [1,2,3,4,5,6]
print(x)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
x = []
print(x)
# Out:
# []

# %%
x = ["wahid ali" , 1 , 1.23]
print(x)
# Out:
# ['wahid ali', 1, 1.23]

# %% [markdown]
# ## List with mixed types

# %%
x = ["wahid ali" , 1 , 1.23]
print(x)
# Out:
# ['wahid ali', 1, 1.23]

# %% [markdown]
# ## Append

# %%
x = [1,2,3,4,5,6,7,8]
x.append(1)
x.sort()
print(x)
# Out:
# [1, 1, 2, 3, 4, 5, 6, 7, 8]
